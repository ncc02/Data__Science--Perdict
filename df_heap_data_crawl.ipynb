# %%
import pandas as pd

df = pd.read_csv('./data-1.csv')
df = df.drop(df.columns[0], axis=1)
df = df.applymap(lambda x: x.strip() if isinstance(x, str) else x)
df
# Out:
#                                    Tên xe             Giá  Năm SX  Kiểu dáng  \
# 0         Toyota Land Cruiser Prado  2015  1 tỉ 480 triệu    2015        SUV
# 1         Ford Ranger XLS 2.2 4x2 AT 2016       499 triệu    2016     BánTải
# 2          Mercedes-Benz E200 2.0 I4 2014       725 triệu    2014      Sedan
# 3     Hyundai Tucson 1.6 Turbo HTRAC 2018       699 triệu    2018        SUV
# 4                       Mazda 6 2.0l 2019       645 triệu    2019      Sedan
# ...                                   ...             ...     ...        ...
# 1000                   Suzuki Swift  2016       368 triệu    2016  Hatchback
# 1001       Toyota Highlander 2.7L LE 2016  1 tỉ 350 triệu    2016        SUV
# 1002                Audi Q2 1.4 TFSI 2018       969 triệu    2018        SUV
# 1003    Mercedes-Benz GLC 300 4MATIC 2021  2 tỉ 038 triệu    2021        SUV
# 1004          Mercedes-Benz C300 AMG 2018  1 tỉ 360 triệu    2018      Sedan
#
#      Tình trạng    Xuất xứ  Km đã đi Tỉnh thành Quận huyện    Hộp số  \
# 0          Xecũ   Nhậpkhẩu  85.000km      HàNội   HoàngMai  Sốtựđộng
# 1          Xecũ   Nhậpkhẩu       NaN      HàNội   HoàngMai  Sốtựđộng
# 2          Xecũ  Trongnước  79.000km      HàNội    CầuGiấy  Sốtựđộng
# 3          Xecũ  Trongnước  60.000km      HàNội    CầuGiấy  Sốtựđộng
# 4          Xecũ  Trongnước  32.000km      HàNội    CầuGiấy  Sốtựđộng
# ...         ...        ...       ...        ...        ...       ...
# 1000       Xecũ  Trongnước  60.000km      HàNội    CầuGiấy  Sốtựđộng
# 1001       Xecũ   Nhậpkhẩu  40.000km      HàNội     BaĐình  Sốtựđộng
# 1002       Xecũ   Nhậpkhẩu  39.000km      HàNội     BaĐình  Sốtựđộng
# 1003       Xecũ  Trongnước   8.000km     Tp.HCM      Quận7  Sốtựđộng
# 1004       Xecũ  Trongnước  19.000km     Tp.HCM      Quận7  Sốtựđộng
#
#      Nhiên liệu
# 0          Xăng
# 1        Diesel
# 2          Xăng
# 3          Xăng
# 4          Xăng
# ...         ...
# 1000       Xăng
# 1001       Xăng
# 1002       Xăng
# 1003       Xăng
# 1004       Xăng
#
# [1005 rows x 11 columns]
